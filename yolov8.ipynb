# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 50.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
from ultralytics import YOLO

# Load model pre-trained
model = YOLO('yolov8n.pt') 

# Train với file data.yaml của bạn
model.train(data='/kaggle/input/datasets/zahydroa/ginhan/data.yaml', epochs=50, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.64 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import shutil
import os

# Tìm kiếm toàn bộ cấu trúc thư mục để xác định nơi lưu kết quả
results_path = None
for root, dirs, files in os.walk('/kaggle/working/'):
    if 'weights' in dirs and 'best.pt' in os.listdir(os.path.join(root, 'weights')):
        results_path = root
        break

if results_path:
    print(f"Tìm thấy kết quả tại: {results_path}")
    output_filename = '/kaggle/working/yolov8_result'
    shutil.make_archive(output_filename, 'zip', results_path)
    print(f"Đã nén xong! File nằm tại: {output_filename}.zip")
else:
    print("Không tìm thấy kết quả train. Hãy kiểm tra xem bạn đã chạy model.train() thành công chưa.")
# Out:
# Tìm thấy kết quả tại: /kaggle/working/runs/detect/train
# Đã nén xong! File nằm tại: /kaggle/working/yolov8_result.zip

# %%
# Copy file notebook của bạn vào thư mục repo
# !cp /kaggle/working/my_training.ipynb /kaggle/working/safety-worker-models/

# Nếu bạn có các file .py hoặc dữ liệu khác cần đẩy, hãy copy tương tự:
# !cp /kaggle/working/data.yaml /kaggle/working/safety-worker-models/
# Out:
# cp: cannot stat '/kaggle/working/my_training.ipynb': No such file or directory
